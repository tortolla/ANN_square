# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt


"""# Папка с изображениями, которые движутся направо
image_folder1 = "Right1"
image_files1 = os.listdir(image_folder1)
#Папка с изображениями, которые движутся налево
image_folder2 = "Left1"
image_files2 = os.listdir(image_folder2)
#Папка с изображениями, которые движутся вверх
image_folder3 = "Up1"
image_files3 = os.listdir(image_folder3)
#Папка с изображениями, которые движутся вниз
image_folder4 = "Down1"
image_files4 = os.listdir(image_folder3)




# Пустой список для хранения массивов изображений
image_data1 = []
image_data2 = []
image_data3 = []
image_data4 = []


# Проход по каждому изображению и преобразование его в массив (Направо)
for image_file in image_files1:
    image_path = os.path.join(image_folder1, image_file)
    image = Image.open(image_path)  # Загрузка изображения
    image_array = np.array(image)   # Преобразование изображения в массив
    image_data1.append(image_array)  # Добавление массива изображения в список

# Преобразование списка массивов изображений в один массив
image_data1 = np.array(image_data1)

# Проход по каждому изображению и преобразование его в массив (Налево)
for image_file in image_files2:
    image_path = os.path.join(image_folder2, image_file)
    image = Image.open(image_path)  # Загрузка изображения
    image_array = np.array(image)   # Преобразование изображения в массив
    image_data2.append(image_array)  # Добавление массива изображения в список

# Преобразование списка массивов изображений в один массив
image_data2 = np.array(image_data2)

# Проход по каждому изображению и преобразование его в массив (Вверх)
for image_file in image_files3:
    image_path = os.path.join(image_folder3, image_file)
    image = Image.open(image_path)  # Загрузка изображения
    image_array = np.array(image)   # Преобразование изображения в массив
    image_data3.append(image_array)  # Добавление массива изображения в список

# Преобразование списка массивов изображений в один массив
image_data3 = np.array(image_data3)

# Проход по каждому изображению и преобразование его в массив (Вниз)
for image_file in image_files4:
    image_path = os.path.join(image_folder4, image_file)
    image = Image.open(image_path)  # Загрузка изображения
    image_array = np.array(image)   # Преобразование изображения в массив
    image_data4.append(image_array)  # Добавление массива изображения в список

# Преобразование списка массивов изображений в один массив
image_data4 = np.array(image_data4)


labels1 = [0]*147  #Метки для каждого изображения, которые движутся направо
labels2 = [1]*147  #Метки для каждого изображения, которые движутся налево
labels3 = [2]*147  #Метки для каждого изображения, которые движутся вверх
labels4 = [3]*147 #Метки для каждого изображения, которые движутся вниз
# Разделение данных на обучающий и тестовый наборы
num_samples1 = len(image_data1)
num_samples2 = len(image_data2)
num_samples3 = len(image_data3)
num_samples4 = len(image_data4)


# Разделение на тренировочный и тестовый наборы (80% - тренировочный, 20% - тестовый)
train_size1 = int(0.8 * num_samples1)
train_size2 = int(0.8 * num_samples2)
train_size3 = int(0.8 * num_samples3)
train_size4 = int(0.8 * num_samples4)


#Направо
X_train1 = image_data1[:train_size1]
y_train1 = labels1[:train_size1]

X_test1 = image_data1[train_size1:]
y_test1 = labels1[train_size1:]

#Налево
X_train2 = image_data2[:train_size2]
y_train2 = labels2[:train_size2]

X_test2 = image_data2[train_size2:]
y_test2 = labels2[train_size2:]

#Вверх
X_train3 = image_data3[:train_size3]
y_train3 = labels3[:train_size3]

X_test3 = image_data3[train_size3:]
y_test3 = labels3[train_size3:]

#Вниз
X_train4 = image_data4[:train_size4]
y_train4 = labels4[:train_size4]

X_test4 = image_data4[train_size4:]
y_test4 = labels4[train_size4:]

#Все вместе
x_train=np.concatenate((X_train1, X_train2, X_train3, X_train4))
y_train=np.concatenate((y_train1, y_train2, y_train3, y_train4))

x_test=np.concatenate((X_test1, X_test2, X_test3, X_test4))
y_test=np.concatenate((y_test1, y_test2, y_test3, y_test4))

print(len(x_train),len(x_train[0]), len(y_train))"""

def load_data():
   data = np.genfromtxt('/content/new.csv', delimiter='\t', dtype=None, encoding=None)
   filtered_data = []
   for i in range(0, len(data), 12):
      filtered_data.append(data[i:i+11])
   filtered_array = np.array(filtered_data)

   n1 = len(filtered_data)
   data_size = int(0.8 * n1)

   x_train = filtered_array[:data_size]
   x_test = filtered_array[data_size:]

   filtered_labels = [row for index, row in enumerate(data) if (index + 1) % 12 == 0]
   filtered_labels_array = np.array(filtered_labels)

   n2 = len(filtered_labels_array)
   labels_size = int(0.8 * n2)
   y = []
   for i in range(len(filtered_labels_array)):
      y.append(filtered_labels_array[i][0])
   y = np.array(y)

   y_train = y[:labels_size]
   y_test = y[labels_size:]

   data_train = (x_train, y_train)
   data_test = (x_test, y_test)

   return data_train, data_test

(x_train, y_train), (x_test, y_test) = load_data()

y_train = np.array(y_train)
y_test = np.array(y_test)

# Создание нейронной сети
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(11, 11)),
    tf.keras.layers.Dense(30, activation='relu'),
    # tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])

# Компиляция модели
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Обучение модели
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))

# Оценка модели
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Loss: {loss}, Accuracy: {accuracy}')


# Обратный вызов для сохранения истории обучения
#history = model.fit(X_train, y_train, epochs=30, validation_data=(X_test, y_test), callbacks=[tf.keras.callbacks.History()])

# Получение значений точности для каждой эпохи
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

print(f"Epoch: {val_accuracy.index(max(val_accuracy)) + 1} Val accuracy: {max(val_accuracy)}")
plt.axis([0,20,0,1])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(list(range(1,21)),val_accuracy, '.')
plt.show()
# Out:
# Epoch 1/20
# 58/58 [==============================] - 1s 7ms/step - loss: 9.2643 - accuracy: 0.5114 - val_loss: 2.6145 - val_accuracy: 0.6652
# Epoch 2/20
# 58/58 [==============================] - 0s 3ms/step - loss: 1.4970 - accuracy: 0.7642 - val_loss: 0.6701 - val_accuracy: 0.7935
# Epoch 3/20
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.8671 - val_loss: 0.1179 - val_accuracy: 0.9630
# Epoch 4/20
# 58/58 [==============================] - 0s 4ms/step - loss: 0.1024 - accuracy: 0.9651 - val_loss: 0.0545 - val_accuracy: 0.9848
# Epoch 5/20
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 0.9875 - val_loss: 0.0392 - val_accuracy: 0.9891
# Epoch 6/20
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9967 - val_loss: 0.0257 - val_accuracy: 0.9978
# Epoch 7/20
# ...

# %%
import matplotlib.pyplot as plt

# Выбор темы для графика
plt.style.use('seaborn-darkgrid')  # Тема seaborn-darkgrid для красивого вида графика

# Задаем размер фигуры
plt.figure(figsize=(10, 5))  # Размер фигуры увеличен до 10x5 дюймов

plt.axis([0, 20, 0, 1])  # Оси графика
plt.xlabel('Epochs')  # Подпись оси X
plt.ylabel('Accuracy')  # Подпись оси Y

# Отрисовка графика
plt.plot(list(range(1, 21)), val_accuracy, '.', markersize=10)  # Увеличение размера точек

# Добавление сетки
plt.grid(True)  # Включение отображения сетки

# Показать график
plt.show()
# Out:
# <ipython-input-12-56aab9d8631f>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')  # Тема seaborn-darkgrid для красивого вида графика

# %%
import matplotlib.pyplot as plt

# Выбор темы для графика
plt.style.use('seaborn-whitegrid')  # Тема seaborn-whitegrid для светлого и чистого вида графика

# Задаем размер фигуры
plt.figure(figsize=(10, 5))  # Размер фигуры увеличен до 10x5 дюймов

plt.axis([0, 20, 0, 1])  # Оси графика
plt.xlabel('Epochs')  # Подпись оси X
plt.ylabel('Accuracy')  # Подпись оси Y

# Отрисовка графика
plt.plot(list(range(1, 21)), val_accuracy, '.', markersize=10)  # Увеличение размера точек

# Показать график
plt.show()
# Out:
# <ipython-input-13-a2979e959071>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')  # Тема seaborn-whitegrid для светлого и чистого вида графика
